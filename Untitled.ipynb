# %%
# basic library
import pandas as pd
import numpy as np

# Eda libr
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from scipy.stats import spearmanr,pearsonr
from scipy.stats import norm
from scipy import stats
import pylab
import plotly.express as px
import scipy.stats as st
# %matplotlib inline

# Remove Warnings
import warnings
warnings.filterwarnings('ignore')

# Split the Data Train and Test
from sklearn.model_selection import train_test_split

# Models Building
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import AdaBoostClassifier

# Scaling and Normalization 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

# Label Encoding 
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# Model Evaluation 
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report

# Learning Curuve
from sklearn.model_selection import learning_curve

# Stats-Model and Vif
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# cross Validation
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# Optimization
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# Feature Selection
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE

# Make PipeLine
from sklearn.pipeline import make_pipeline

# Dime Reduction
from sklearn.decomposition import PCA

# Date and Time
import datetime
import time

import tqdm
from tqdm import tqdm_notebook


from sklearn.tree import export_graphviz
import pydotplus
#from sklearn.externals.six import StringIO    
from six import StringIO
from IPython.display import Image
import sklearn


print("All Libraries Imported")
print(" ")
# Out:
# All Libraries Imported

# %%
df = pd.read_csv('DS_dataset.csv')

# %%
df.head()
# Out:
#    Customer_ID    Var1    Var2 Group Category  Rating  Purchased_ABC_product
# 0         5518  41.534  12.123    G1       C1  Bronze                      0
# 1        40515   9.445   0.256    G1       C1  Bronze                      0
# 2        52697  37.599   3.199    G1       C2    Gold                      0
# 3        68202  81.514   1.645    G1       C1  Silver                      0
# 4       130003  46.805   1.706    G1       C1  Silver                      0

# %%
def data_head(df):
    return df.head()

def data_tail(df):
    return df.tail()

def data_1_to_20(df):
    return df.head(n = 20)

def data_missing_with_missing_go(df):
    msno.matrix(df,figsize=(12,6))
    plt.show()
    
def data_missing_heat_map(df):
    plt.figure(figsize=(12,6))
    sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
    plt.show()
    
def data_missing_heat_map2(df):
    plt.figure(figsize=(12,6))
    sns.heatmap(df.notna())
    plt.show()
    
def data_missing(df):
    return df.isnull().sum()

def data_missing2(df):
    for col in df.columns:
        a =df[col].isnull().sum()
        print(col,a)
        print(" ")

def data_missing_columns(df):
    return df.columns[df.isnull().any()]

def data_missing_values_percentage(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = ((df.isnull().sum())*100)/df.isnull().count().sort_values(ascending=False)
    missing_data=pd.concat([total, percent], axis=1, keys=['Total','Percent'], sort=False).sort_values('Total', ascending=False)
    print(missing_data)
    
def data_missing_values_percentage2(df):
    return df.isnull().mean()
    
def data_missing__values_barplot(data):
    total = data.isnull().sum().sort_values(ascending = False)
    percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False)
    ms=pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    ms= ms[ms["Percent"] > 0]
    f,ax =plt.subplots(figsize=(8,6))
    plt.xticks(rotation='90')
    fig=sns.barplot(ms.index, ms["Percent"],color="green",alpha=0.8)
    plt.xlabel('Features', fontsize=15)
    plt.ylabel('Percent of missing values', fontsize=15)
    plt.title('Percent missing data by feature', fontsize=15)
    return ms

def data_missing__values_barplot2(df):
    missing_df = df.isnull().sum(axis=0).reset_index()
    missing_df.columns = ['column_name', 'missing_count']
    missing_df = missing_df.loc[missing_df['missing_count']>0]
    missing_df = missing_df.sort_values(by='missing_count')

    ind = np.arange(missing_df.shape[0])
    width = 0.9
    fig, ax = plt.subplots(figsize=(10,8))
    rects = ax.barh(ind, missing_df.missing_count.values, color='blue')
    ax.set_yticks(ind)
    ax.set_yticklabels(missing_df.column_name.values, rotation='horizontal')
    ax.set_xlabel("Count of missing values")
    ax.set_title("Number of missing values in each column")
    plt.show()
    
def data_data_types(df):
    return df.dtypes
    
def data_table_describe(df):
    return df.describe()

def data_describe_each_feature(df):
    for col in df[num]:
        mask = df[col].describe()
        print(col,"\n",mask)
        print(" ")

def data_table_corr(df):
    return df.corr()

def data_info(df):
    return df.info()

def data_shape(df):
    return df.shape

def data_data_frame_Transpose(df):
    return df.T

def data_index(df):
    return df.index

def data_count(df):
    return df.count()

def data_display_all_rows_and_columns(df):
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_rows', None)

def data_num_and_cat(df):
    cat = []
    num = []
    for col in df.columns:
        if df[col].dtype=='O':
            cat.append(col)
        else:
            num.append(col)
    return num,cat

def data_heatmap(df):
    plt.figure(figsize=(18,11))
    sns.heatmap(df.corr(),annot=True,cmap='Reds')
    plt.show()
    
def data_heatmap2(df):
    plt.figure(figsize=(18,11))
    sns.heatmap(df.corr(),annot=True,cmap='Blues')
    plt.show()

def data_heatmap3(df):
    plt.figure(figsize=(18,11))
    sns.heatmap(df.corr(),annot=True,cmap='YlGnBu')
    plt.show()
    
def data_heatmap_no_annot(df):
    plt.figure(figsize=(18,11))
    sns.heatmap(df.corr(),annot=False,cmap='Reds')
    plt.show()
    
def data_heatmap_no_annot2(df):
    plt.figure(figsize=(18,11))
    sns.heatmap(df.corr(),annot=False,cmap='viridis')
    plt.show()
    
def data_heat_map_other(df):
    plt.figure(figsize=(18,11))
    return (df.corr().style.background_gradient(cmap='coolwarm'))

def data_heat_map_other2(df):
    corr = df.corr()
    cut_off = 0.1
    corr = corr[(corr > cut_off) | (corr < -cut_off)]
    plt.subplots(figsize=(18,11));
    sns.heatmap(corr, cmap="RdBu", square=True, annot=False, cbar_kws={"shrink": .6}, )
    plt.title(f"Correlation of features greater than +/-{cut_off}")
    plt.tight_layout()
    plt.show()
    
def data_heat_map_other3(df):
    corrMatt = df.corr()
    mask = np.array(corrMatt)
    mask[np.tril_indices_from(mask)] = False
    fig,ax= plt.subplots()
    fig.set_size_inches(18,11)
    sns.heatmap(corrMatt, mask=mask,vmax=.8, square=True,annot=True)
    plt.show()
    
def data_check_corr(df):
    corr = df.corr()
    plt.figure(figsize=(16,9));
    corr["Purchased_ABC_product"].sort_values(ascending=True)[:-1].plot(kind="barh")
    plt.xlabel("Correlation")
    plt.tight_layout()
    plt.show()
    
def data_check_corr2(df):
    labels = []
    values = []
    for col in df:
        if col not in ["Purchased_ABC_product"]:
            labels.append(col)
            values.append(spearmanr(df[col].values, df["Purchased_ABC_product"].values)[0])
    corr_df = pd.DataFrame({'col_labels':labels, 'corr_values':values})
    corr_df = corr_df.sort_values(by='corr_values')
    ind = np.arange(corr_df.shape[0])
    width = 0.9
    fig, ax = plt.subplots(figsize=(12,15))
    rects = ax.barh(ind, np.array(corr_df.corr_values.values), color='g')
    ax.set_yticks(ind)
    ax.set_yticklabels(corr_df.col_labels.values, rotation='horizontal')
    ax.set_xlabel("Correlation coefficient")
    ax.set_title("Correlation coefficient of the variables")
    plt.show()
    
def data_heat_map_cluster_map(df):
    sns.clustermap(df.corr(), annot=True, linewidths=.6, fmt= '.2f', figsize=(15, 10))
    plt.show()
    
def data_data_info(df):
    return df.info()
        
def data_display_all_columns(df):
    return (df.columns)

def data_df_size(df):
    for col in df.columns:
        print(col,df[col].size)
        print(" ")
    return print("Total size of Data_Frame ",df.size)

def data_check_unique_featues_columns(df):
    for col in df.columns:
        print('variable',col,' has unique elemnts  \n',len(df[col].unique()))
        print(" \n" )
    print('Total Number of Elements \n',len(df))
    
def data_print_unique_features(df):
    for col in df.columns:
        print('variable',col,' its unique elemnts  \n',df[col].unique())
        print(" \n ")
        
def data_display_unique_features_with_size(df):
    for col in df.columns:
        print(" \n ")
        print(col,len(df[col].unique()))
        print(" ")
        print(df[col].unique()[:30])
        print(" ")
        
def data_value_counts_all_columns(df):
    for col in df.columns:
        x = df[col].value_counts()
        print("Column name is:",col,"and it value is:",x)
        print(" \n ")
        
def data_show_valuecounts_perc(df):
    for col in df.columns:
        print(col,df[col].value_counts() / len(df))
        print(" ")
        
def data_value_counts_bins(df):
    for col in df.columns:
        return df[col].value_counts(bins = 5, ascending = True)
    
def data_value_counts_bins2(df):
    for col in df.columns:
        return df[col].value_counts(bins = 10, ascending = True)
    
def data_data_sort_values(df):
    for col in df.columns:
        print(col,df[col].sort_values())
        print(" ")
        
def data_data_rank(df):
    for col in df.columns:
        print(col,df[col].rank())
        print(" ")

# works with numeric features
def data_nunique(df):
    for col in df.columns:
        print(col,df[col].nunique())
        print(" ")
        
def data_nlargest(df):
    for col in df[num].columns:
        print(col,"\n",df.nlargest(10,col))
        print(" ")
        
def data_nsmallest(df):
    for col in df[num].columns:
        print(col,"\n",df.nsmallest(10,col))
        print(" ")
        
def data_index_max(df):
    return df[num].idxmax()

def data_index_min(df):
    return df[num].idxmin()
        
def data_check_outliers(df):
    for col in df[num]:
        q = df[col].describe()
        IQR    = q['75%'] - q['25%']
        Upper  = q['75%'] + 1.5 * IQR
        Lower  = q['25%'] - 1.5 * IQR
        print("the upper and lower outliers are {} and {} of \n {}".format(Upper,Lower,col)) 
        
def data_check_outliers2(df):
    for col in df[num].columns:
        IQR = df[col].quantile(0.75) - df[col].quantile(0.25)
        Lower_fence = df[col].quantile(0.25) - (IQR * 1.5)
        Upper_fence = df[col].quantile(0.75) + (IQR * 1.5)

        print("Feature ",col, "\n" "Upper frence  \t  ",Upper_fence,"\t" "Lower frence      ",Lower_fence,"IQR    ",IQR)
        print(" \t ")
        
def data_check_outliers_extreme_values(df):
    for col in df[num].columns:
        IQR = df[col].quantile(0.75) - df[col].quantile(0.25)
        Lower_fence = df[col].quantile(0.25) - (IQR * 3)
        Upper_fence = df[col].quantile(0.75) + (IQR * 3)

        print("Feature ",col, "\n" "Upper frence  \t  ",Upper_fence,"\t" "Lower frence      ",Lower_fence,"\t" "IQR    ",IQR)
        print(" \t ")
        
def data_data_quants(df):
    for col in df[num].columns:
        quants = [0.05, 0.25, 0.5, 0.75, 0.95]
        mask = df[col].quantile(quants)
        return mask
        
def data_range(df):
    for col in df[num].columns:
        print(col,'---Range--- \n ',df[col].max()-df[col].min())
        print(" \n ")
        
def data_df_max(df):
    return df.max()

def data_df_min(df):
    return df.min()

def data_df_mean(df):
    return df.mean()

def data_df_medain(df):
    return df.median()

def data_df_std(df):
    return df.std()

def data_check_distribution_normality_values(df):
    for col in df[num]:
        upper_boundry = df[col].mean() + 3* df[col].std()
        lower_boundry = df[col].mean() - 3* df[col].std()
        print(col,"\n ",upper_boundry,lower_boundry)
        print(" ")
        
def data_sample(df):
    return df.sample(n = 20)

def check_Pearsons_corr(df):
    for col in df[num].columns:
        corr, _ = pearsonr(df[col],df[col])
        print(" ")
        print(col,'Pearsons correlation: %.3f' % corr)
        
def check_spearmanr_corr(df):
    for col in df[num].columns:
        corr, _ = spearmanr(df[col],df[col])
        print(" ")
        print(col,'spearmanr correlation: %.3f' % corr)
        
def check_Skewness(df):
    for col in df[num].columns:
        print(" ")
        print(col,"Skewness: %f" % df[col].skew())
        
def check_Kurtosis(df):
    for col in df[num].columns:
        print(" ")
        print(col,"Kurtosis: %f" % df[col].kurt())
        


print("All Basic Preprocessing Function Imported")
print(" ")
# Out:
# All Basic Preprocessing Function Imported

# %%
cat = []
num = []
for col in df.columns:
    if df[col].dtype=='O':
        cat.append(col)
    else:
        num.append(col)

print("Divided data into Numeric and cat \n")
print(" ")
# Out:
# Divided data into Numeric and cat

# %%
num
# Out:
# ['Customer_ID', 'Var1', 'Var2', 'Purchased_ABC_product']

# %%
cat
# Out:
# ['Group', 'Category', 'Rating']

# %%
for label,content in df.items():
    if pd.api.types.is_numeric_dtype(content):
            print(label)
# Out:
# Customer_ID
# Var1
# Var2
# Purchased_ABC_product

# %%
for label,content in df.items():
    if pd.api.types.is_string_dtype(content):
        print(label)
# Out:
# Group
# Category
# Rating

# %%
df[num].head()
# Out:
#    Customer_ID    Var1    Var2  Purchased_ABC_product
# 0         5518  41.534  12.123                      0
# 1        40515   9.445   0.256                      0
# 2        52697  37.599   3.199                      0
# 3        68202  81.514   1.645                      0
# 4       130003  46.805   1.706                      0

# %%
df[cat].head()
# Out:
#   Group Category  Rating
# 0    G1       C1  Bronze
# 1    G1       C1  Bronze
# 2    G1       C2    Gold
# 3    G1       C1  Silver
# 4    G1       C1  Silver

# %%
data_head(df)
# Out:
#    Customer_ID    Var1    Var2 Group Category  Rating  Purchased_ABC_product
# 0         5518  41.534  12.123    G1       C1  Bronze                      0
# 1        40515   9.445   0.256    G1       C1  Bronze                      0
# 2        52697  37.599   3.199    G1       C2    Gold                      0
# 3        68202  81.514   1.645    G1       C1  Silver                      0
# 4       130003  46.805   1.706    G1       C1  Silver                      0

# %%
data_tail(df)
# Out:
#        Customer_ID    Var1   Var2 Group Category  Rating  \
# 30824      7047231  12.094  0.899    G5       C3  Bronze
# 30825      7079889  43.214  6.484    G5       C1  Bronze
# 30826      7155901  20.902  6.159    G5       C1  Bronze
# 30827      7180919  11.443  0.000    G5       C3  Bronze
# 30828      7182208  18.485  0.164    G5       C4  Bronze
#
#        Purchased_ABC_product
# 30824                      1
# 30825                      1
# 30826                      1
# 30827                      0
# 30828                      0

# %%
data_1_to_20(df)
# Out:
#     Customer_ID    Var1    Var2 Group Category  Rating  Purchased_ABC_product
# 0          5518  41.534  12.123    G1       C1  Bronze                      0
# 1         40515   9.445   0.256    G1       C1  Bronze                      0
# 2         52697  37.599   3.199    G1       C2    Gold                      0
# 3         68202  81.514   1.645    G1       C1  Silver                      0
# 4        130003  46.805   1.706    G1       C1  Silver                      0
# 5        175229  19.222   2.133    G1       C3  Silver                      0
# 6        175295  41.091   2.536    G1       C4  Silver                      1
# 7        181524  96.706   9.295    G1       C1    Gold                      1
# 8        183955  82.989   5.431    G1       C2    Gold                      1
# 9        232643   2.009   1.084    G1       C1  Silver                      1
# 10       241012  16.994   0.298    G1       C1  Bronze                      0
# 11       242249  73.599   7.032    G1       C2  Silver                      1
# 12       404966  15.662   1.064    G1       C1    Gold                      1
# 13       417265  22.799   0.000    G1       C1  Bronze                      0
# 14       419000  26.937   2.109    G1       C1  Bronze                      1
# 15       679877   7.730   0.917    G1       C1  Bronze                      0
# 16       695148   9.572   0.000    G1       C1  Bronze                      0
# 17       699073   2.804   0.168    G1       C1  Bronze                      0
# 18       720912  26.807   1.382    G1       C1  Bronze                      0
# 19       721109  27.819   0.000    G1       C5  Silver                      0

# %%
data_missing(df)
# Out:
# Customer_ID              0
# Var1                     0
# Var2                     0
# Group                    0
# Category                 0
# Rating                   0
# Purchased_ABC_product    0
# dtype: int64

# %%
data_missing_heat_map(df)

# %%
data_data_types(df)
# Out:
# Customer_ID                int64
# Var1                     float64
# Var2                     float64
# Group                     object
# Category                  object
# Rating                    object
# Purchased_ABC_product      int64
# dtype: object

# %%
data_table_describe(df)
# Out:
#         Customer_ID          Var1          Var2  Purchased_ABC_product
# count  3.082900e+04  30829.000000  30829.000000           30829.000000
# mean   3.057482e+06     64.868318      4.994489               0.503552
# std    2.210470e+06    114.373345      9.533546               0.499995
# min    6.470000e+02      0.251000      0.000000               0.000000
# 25%    1.501804e+06     13.256000      0.668000               0.000000
# 50%    2.192582e+06     31.860000      2.189000               1.000000
# 75%    4.732076e+06     68.702000      5.482000               1.000000
# max    7.285914e+06   2909.776000    317.380000               1.000000

# %%
data_describe_each_feature(df)
# Out:
# Customer_ID
#  count    3.082900e+04
# mean     3.057482e+06
# std      2.210470e+06
# min      6.470000e+02
# 25%      1.501804e+06
# 50%      2.192582e+06
# 75%      4.732076e+06
# max      7.285914e+06
# Name: Customer_ID, dtype: float64
#
# Var1
#  count    30829.000000
# mean        64.868318
# std        114.373345
# min          0.251000
# 25%         13.256000
# 50%         31.860000
# 75%         68.702000
# max       2909.776000
# Name: Var1, dtype: float64
#
# Var2
#  count    30829.000000
# mean         4.994489
# std          9.533546
# min          0.000000
# 25%          0.668000
# 50%          2.189000
# 75%          5.482000
# max        317.380000
# Name: Var2, dtype: float64
#
# Purchased_ABC_product
#  count    30829.000000
# mean         0.503552
# std          0.499995
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: Purchased_ABC_product, dtype: float64

# %%
data_table_corr(df)
# Out:
#                        Customer_ID      Var1      Var2  Purchased_ABC_product
# Customer_ID               1.000000  0.002707  0.049997               0.037436
# Var1                      0.002707  1.000000  0.878002               0.316515
# Var2                      0.049997  0.878002  1.000000               0.350131
# Purchased_ABC_product     0.037436  0.316515  0.350131               1.000000

# %%
data_info(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30829 entries, 0 to 30828
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            30829 non-null  int64
#  1   Var1                   30829 non-null  float64
#  2   Var2                   30829 non-null  float64
#  3   Group                  30829 non-null  object
#  4   Category               30829 non-null  object
#  5   Rating                 30829 non-null  object
#  6   Purchased_ABC_product  30829 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.6+ MB

# %%
data_shape(df)
# Out:
# (30829, 7)

# %%
data_data_frame_Transpose(df)
# Out:
#                         0       1       2       3       4       5       6      \
# Customer_ID              5518   40515   52697   68202  130003  175229  175295
# Var1                   41.534   9.445  37.599  81.514  46.805  19.222  41.091
# Var2                   12.123   0.256   3.199   1.645   1.706   2.133   2.536
# Group                      G1      G1      G1      G1      G1      G1      G1
# Category                   C1      C1      C2      C1      C1      C3      C4
# Rating                 Bronze  Bronze    Gold  Silver  Silver  Silver  Silver
# Purchased_ABC_product       0       0       0       0       0       0       1
#
#                         7       8       9      ...    30819    30820    30821  \
# Customer_ID            181524  183955  232643  ...  6860917  6894858  6929365
# Var1                   96.706  82.989   2.009  ...   22.437  133.254   34.106
# Var2                    9.295   5.431   1.084  ...    1.054    5.746    6.589
# Group                      G1      G1      G1  ...       G1       G5       G5
# Category                   C1      C2      C1  ...       C3       C1       C3
# Rating                   Gold    Gold  Silver  ...   Bronze   Silver   Silver
# Purchased_ABC_product       1       1       1  ...        0        1        1
#
#                          30822    30823    30824    30825    30826    30827  \
# Customer_ID            6950888  6993816  7047231  7079889  7155901  7180919
# Var1                    46.724    6.524   12.094   43.214   20.902   11.443
# Var2                     3.387    0.918    0.899    6.484    6.159      0.0
# Group                       G5       G1       G5       G5       G5       G5
# Category                    C1       C3       C3       C1       C1       C3
# Rating                  Bronze   Bronze   Bronze   Bronze   Bronze   Bronze
# Purchased_ABC_product        1        0        1        1        1        0
#
#                          30828
# Customer_ID            7182208
# Var1                    18.485
# Var2                     0.164
# Group                       G5
# Category                    C4
# Rating                  Bronze
# Purchased_ABC_product        0
#
# [7 rows x 30829 columns]

# %%
data_index(df)
# Out:
# RangeIndex(start=0, stop=30829, step=1)

# %%
data_count(df)
# Out:
# Customer_ID              30829
# Var1                     30829
# Var2                     30829
# Group                    30829
# Category                 30829
# Rating                   30829
# Purchased_ABC_product    30829
# dtype: int64

# %%
data_heatmap(df)

# %%
data_heatmap2(df)

# %%
data_heatmap3(df)

# %%
data_heatmap_no_annot(df)

# %%
data_heatmap_no_annot2(df)

# %%
data_heat_map_other(df)
# Out:
# <style  type="text/css" >
# #T_83bf9_row0_col0,#T_83bf9_row1_col1,#T_83bf9_row2_col2,#T_83bf9_row3_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_83bf9_row0_col1,#T_83bf9_row0_col2,#T_83bf9_row0_col3,#T_83bf9_row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_83bf9_row1_col2{
#             background-color:  #de614d;
#             color:  #000000;
#         }#T_83bf9_row1_col3{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_83bf9_row2_col0{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_83bf9_row2_col1{
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }#T_83bf9_row2_col3{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_83bf9_row3_col0{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_83bf9_row3_col1,#T_83bf9_row3_col2{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }</style><table id="T_83bf9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Customer_ID</th>        <th class="col_heading level0 col1" >Var1</th>        <th class="col_heading level0 col2" >Var2</th>        <th class="col_heading level0 col3" >Purchased_ABC_product</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83bf9_level0_row0" class="row_heading level0 row0" >Customer_ID</th>
#                         <td id="T_83bf9_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_83bf9_row0_col1" class="data row0 col1" >0.002707</td>
#                         <td id="T_83bf9_row0_col2" class="data row0 col2" >0.049997</td>
#                         <td id="T_83bf9_row0_col3" class="data row0 col3" >0.037436</td>
#             </tr>
#             <tr>
#                         <th id="T_83bf9_level0_row1" class="row_heading level0 row1" >Var1</th>
#                         <td id="T_83bf9_row1_col0" class="data row1 col0" >0.002707</td>
#                         <td id="T_83bf9_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_83bf9_row1_col2" class="data row1 col2" >0.878002</td>
#                         <td id="T_83bf9_row1_col3" class="data row1 col3" >0.316515</td>
#             </tr>
#             <tr>
#                         <th id="T_83bf9_level0_row2" class="row_heading level0 row2" >Var2</th>
#                         <td id="T_83bf9_row2_col0" class="data row2 col0" >0.049997</td>
#                         <td id="T_83bf9_row2_col1" class="data row2 col1" >0.878002</td>
#                         <td id="T_83bf9_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_83bf9_row2_col3" class="data row2 col3" >0.350131</td>
#             </tr>
#             <tr>
#                         <th id="T_83bf9_level0_row3" class="row_heading level0 row3" >Purchased_ABC_product</th>
#                         <td id="T_83bf9_row3_col0" class="data row3 col0" >0.037436</td>
#                         <td id="T_83bf9_row3_col1" class="data row3 col1" >0.316515</td>
#                         <td id="T_83bf9_row3_col2" class="data row3 col2" >0.350131</td>
#                         <td id="T_83bf9_row3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
data_heat_map_other2(df)

# %%
data_heat_map_other3(df)

# %%
data_check_corr(df)

# %%
data_check_corr2(df)

# %%
data_heat_map_cluster_map(df)

# %%
data_info(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30829 entries, 0 to 30828
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            30829 non-null  int64
#  1   Var1                   30829 non-null  float64
#  2   Var2                   30829 non-null  float64
#  3   Group                  30829 non-null  object
#  4   Category               30829 non-null  object
#  5   Rating                 30829 non-null  object
#  6   Purchased_ABC_product  30829 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.6+ MB

# %%
data_df_size(df)
# Out:
# Customer_ID 30829
#
# Var1 30829
#
# Var2 30829
#
# Group 30829
#
# Category 30829
#
# Rating 30829
#
# Purchased_ABC_product 30829
#
# Total size of Data_Frame  215803

# %%
data_display_all_columns(df)
# Out:
# Index(['Customer_ID', 'Var1', 'Var2', 'Group', 'Category', 'Rating',
#        'Purchased_ABC_product'],
#       dtype='object')

# %%
data_check_unique_featues_columns(df)
# Out:
# variable Customer_ID  has unique elemnts
#  30829
#
#
# variable Var1  has unique elemnts
#  26050
#
#
# variable Var2  has unique elemnts
#  10982
#
#
# variable Group  has unique elemnts
#  8
#
#
# variable Category  has unique elemnts
#  5
#
#
# variable Rating  has unique elemnts
#  3
#
#
# variable Purchased_ABC_product  has unique elemnts
#  2
#
#
# Total Number of Elements
#  30829

# %%
data_print_unique_features(df)
# Out:
# variable Customer_ID  its unique elemnts
#  [   5518   40515   52697 ... 7155901 7180919 7182208]
#
#
# variable Var1  its unique elemnts
#  [41.534  9.445 37.599 ...  6.524 43.214 18.485]
#
#
# variable Var2  its unique elemnts
#  [12.123  0.256  3.199 ...  0.798 17.258  6.589]
#
#
# variable Group  its unique elemnts
#  ['G1' 'G2' 'G3' 'G4' 'G5' 'G6' 'G7' 'G8']
#
#
# variable Category  its unique elemnts
#  ['C1' 'C2' 'C3' 'C4' 'C5']
#
#
# variable Rating  its unique elemnts
#  ['Bronze' 'Gold' 'Silver']
#
#
# variable Purchased_ABC_product  its unique elemnts
#  [0 1]

# %%
data_display_unique_features_with_size(df)
# Out:
#
#
# Customer_ID 30829
#
# [  5518  40515  52697  68202 130003 175229 175295 181524 183955 232643
#  241012 242249 404966 417265 419000 679877 695148 699073 720912 721109
#  731272 735844 738276 749060 761497 761970 764437 773526 774619 777808]
#
#
#
# Var1 26050
#
# [ 41.534   9.445  37.599  81.514  46.805  19.222  41.091  96.706  82.989
#    2.009  16.994  73.599  15.662  22.799  26.937   7.73    9.572   2.804
#   26.807  27.819   7.304  22.866  74.01  185.179   6.438  78.627  44.314
#   26.868   5.491  36.349]
#
#
#
# Var2 10982
#
# [12.123  0.256  3.199  1.645  1.706  2.133  2.536  9.295  5.431  1.084
#   0.298  7.032  1.064  0.     2.109  0.917  0.168  1.382  1.004  0.572
#  16.692 10.222  0.247  1.224  1.012  1.687  0.231  2.558  4.771  1.631]
#
#
#
# Group 8
#
# ['G1' 'G2' 'G3' 'G4' 'G5' 'G6' 'G7' 'G8']
#
#
#
# Category 5
#
# ['C1' 'C2' 'C3' 'C4' 'C5']
#
#
#
# Rating 3
#
# ['Bronze' 'Gold' 'Silver']
#
#
#
# Purchased_ABC_product 2
#
# [0 1]

# %%
data_value_counts_all_columns(df)
# Out:
# Column name is: Customer_ID and it value is: 4718592    1
# 3584707    1
# 6240455    1
# 5018471    1
# 6785892    1
#           ..
# 144972     1
# 3409482    1
# 1273415    1
# 3555482    1
# 816070     1
# Name: Customer_ID, Length: 30829, dtype: int64
#
#
# Column name is: Var1 and it value is: 5.608      81
# 2.804      65
# 5.594      31
# 8.412      29
# 2.795      16
#            ..
# 108.896     1
# 48.545      1
# 3.492       1
# 16.233      1
# 19.559      1
# Name: Var1, Length: 26050, dtype: int64
#
#
# Column name is: Var2 and it value is: 0.000     4192
# 0.904       48
# 0.903       39
# 0.900       30
# 0.901       27
#           ...
# 17.037       1
# 9.802        1
# 46.102       1
# 9.654        1
# 4.937        1
# Name: Var2, Length: 10982, dtype: int64
#
#
# Column name is: Group and it value is: G1    19365
# G5     8558
# G3     1762
# G4      494
# G6      312
# G2      298
# G7       21
# G8       19
# Name: Group, dtype: int64
#
#
# Column name is: Category and it value is: C1    14934
# C3     6707
# C2     4031
# C5     2993
# C4     2164
# Name: Category, dtype: int64
#
#
# Column name is: Rating and it value is: Bronze    15127
# Silver    10171
# Gold       5531
# Name: Rating, dtype: int64
#
#
# Column name is: Purchased_ABC_product and it value is: 1    15524
# 0    15305
# Name: Purchased_ABC_product, dtype: int64

# %%
data_show_valuecounts_perc(df)
# Out:
# Customer_ID 4718592    0.000032
# 3584707    0.000032
# 6240455    0.000032
# 5018471    0.000032
# 6785892    0.000032
#              ...
# 144972     0.000032
# 3409482    0.000032
# 1273415    0.000032
# 3555482    0.000032
# 816070     0.000032
# Name: Customer_ID, Length: 30829, dtype: float64
#
# Var1 5.608      0.002627
# 2.804      0.002108
# 5.594      0.001006
# 8.412      0.000941
# 2.795      0.000519
#              ...
# 108.896    0.000032
# 48.545     0.000032
# 3.492      0.000032
# 16.233     0.000032
# 19.559     0.000032
# Name: Var1, Length: 26050, dtype: float64
#
# Var2 0.000     0.135976
# 0.904     0.001557
# 0.903     0.001265
# 0.900     0.000973
# 0.901     0.000876
#             ...
# 17.037    0.000032
# 9.802     0.000032
# 46.102    0.000032
# 9.654     0.000032
# 4.937     0.000032
# Name: Var2, Length: 10982, dtype: float64
#
# Group G1    0.628142
# G5    0.277596
# G3    0.057154
# G4    0.016024
# G6    0.010120
# G2    0.009666
# G7    0.000681
# G8    0.000616
# Name: Group, dtype: float64
#
# Category C1    0.484414
# C3    0.217555
# C2    0.130754
# C5    0.097084
# C4    0.070194
# Name: Category, dtype: float64
#
# Rating Bronze    0.490674
# Silver    0.329917
# Gold      0.179409
# Name: Rating, dtype: float64
#
# Purchased_ABC_product 1    0.503552
# 0    0.496448
# Name: Purchased_ABC_product, dtype: float64

# %%
data_value_counts_bins(df)
# Out:
# (2914753.8, 4371807.2]     2292
# (4371807.2, 5828860.6]     3701
# (5828860.6, 7285914.0]     6024
# (-6638.268, 1457700.4]     7673
# (1457700.4, 2914753.8]    11139
# Name: Customer_ID, dtype: int64

# %%
data_value_counts_bins2(df)
# Out:
# (5100333.9, 5828860.6]     695
# (3643280.5, 4371807.2]    1121
# (2914753.8, 3643280.5]    1171
# (5828860.6, 6557387.3]    2149
# (4371807.2, 5100333.9]    3006
# (729173.7, 1457700.4]     3377
# (2186227.1, 2914753.8]    3502
# (6557387.3, 7285914.0]    3875
# (-6638.268, 729173.7]     4296
# (1457700.4, 2186227.1]    7637
# Name: Customer_ID, dtype: int64

# %%
data_data_sort_values(df)
# Out:
# Customer_ID 9051         647
# 14970        742
# 20617        795
# 26236        832
# 28527        873
#           ...
# 29598    7276895
# 6899     7281474
# 29599    7281555
# 3404     7281830
# 14045    7285914
# Name: Customer_ID, Length: 30829, dtype: int64
#
# Var1 9616        0.251
# 24999       0.254
# 29176       0.348
# 4130        0.358
# 23650       0.530
#            ...
# 16812    1700.419
# 23441    1784.045
# 14782    1988.040
# 16613    2094.866
# 24823    2909.776
# Name: Var1, Length: 30829, dtype: float64
#
# Var2 17388      0.000
# 14095      0.000
# 3148       0.000
# 14087      0.000
# 14086      0.000
#           ...
# 16613    178.064
# 5747     190.876
# 3309     204.999
# 21843    282.688
# 24823    317.380
# Name: Var2, Length: 30829, dtype: float64
#
# Group 0        G1
# 26412    G1
# 15082    G1
# 15081    G1
# 26413    G1
#          ..
# 13824    G8
# 28659    G8
# 12015    G8
# 11872    G8
# 30672    G8
# Name: Group, Length: 30829, dtype: object
#
# Category 0        C1
# 16939    C1
# 16938    C1
# 16937    C1
# 16936    C1
#          ..
# 19570    C5
# 1330     C5
# 28104    C5
# 19716    C5
# 20441    C5
# Name: Category, Length: 30829, dtype: object
#
# Rating 0        Bronze
# 17031    Bronze
# 17027    Bronze
# 17026    Bronze
# 17023    Bronze
#           ...
# 19421    Silver
# 5609     Silver
# 19423    Silver
# 19426    Silver
# 20484    Silver
# Name: Rating, Length: 30829, dtype: object
#
# Purchased_ABC_product 0        0
# 17052    0
# 17051    0
# 17050    0
# 17048    0
#         ..
# 18073    1
# 18072    1
# 6280     1
# 18078    1
# 20516    1
# Name: Purchased_ABC_product, Length: 30829, dtype: int64

# %%
data_data_rank(df)
# Out:
# Customer_ID 0           33.0
# 1          221.0
# 2          278.0
# 3          358.0
# 4          829.0
#           ...
# 30824    29851.0
# 30825    30047.0
# 30826    30414.0
# 30827    30591.0
# 30828    30604.0
# Name: Customer_ID, Length: 30829, dtype: float64
#
# Var1 0        18223.0
# 1         5575.0
# 2        17150.5
# 3        24510.0
# 4        19451.0
#           ...
# 30824     7109.0
# 30825    18648.0
# 30826    11415.5
# 30827     6769.5
# 30828    10312.0
# Name: Var1, Length: 30829, dtype: float64
#
# Var2 0        27883.0
# 1         5488.5
# 2        18630.0
# 3        13079.0
# 4        13279.5
#           ...
# 30824     8540.0
# 30825    24419.5
# 30826    24012.5
# 30827     2096.5
# 30828     4522.0
# Name: Var2, Length: 30829, dtype: float64
#
# Group 0         9683.0
# 1         9683.0
# 2         9683.0
# 3         9683.0
# 4         9683.0
#           ...
# 30824    26198.5
# 30825    26198.5
# 30826    26198.5
# 30827    26198.5
# 30828    26198.5
# Name: Group, Length: 30829, dtype: float64
#
# Category 0         7467.5
# 1         7467.5
# 2        16950.0
# 3         7467.5
# 4         7467.5
#           ...
# 30824    22319.0
# 30825     7467.5
# 30826     7467.5
# 30827    22319.0
# 30828    26754.5
# Name: Category, Length: 30829, dtype: float64
#
# Rating 0         7564.0
# 1         7564.0
# 2        17893.0
# 3        25744.0
# 4        25744.0
#           ...
# 30824     7564.0
# 30825     7564.0
# 30826     7564.0
# 30827     7564.0
# 30828     7564.0
# Name: Rating, Length: 30829, dtype: float64
#
# Purchased_ABC_product 0         7653.0
# 1         7653.0
# 2         7653.0
# 3         7653.0
# 4         7653.0
#           ...
# 30824    23067.5
# 30825    23067.5
# 30826    23067.5
# 30827     7653.0
# 30828     7653.0
# Name: Purchased_ABC_product, Length: 30829, dtype: float64

# %%
data_nunique(df)
# Out:
# Customer_ID 30829
#
# Var1 26050
#
# Var2 10982
#
# Group 8
#
# Category 5
#
# Rating 3
#
# Purchased_ABC_product 2

# %%
data_nlargest(df)
# Out:
# Customer_ID
#         Customer_ID     Var1    Var2 Group Category  Rating  \
# 14045      7285914  265.535  13.964    G5       C4    Gold
# 3404       7281830    7.050   0.269    G5       C1  Bronze
# 29599      7281555   28.385   2.587    G5       C1  Silver
# 6899       7281474   68.958   6.546    G5       C4  Silver
# 29598      7276895  393.570  44.352    G5       C5    Gold
# 26716      7276045   14.251   0.536    G5       C1  Bronze
# 12954      7272468   23.514   3.692    G5       C3  Bronze
# 26543      7271560   45.630   7.892    G5       C3  Silver
# 17626      7271557   31.490   1.834    G5       C4  Silver
# 27513      7270287   16.300   1.500    G5       C1  Bronze
#
#        Purchased_ABC_product
# 14045                      1
# 3404                       0
# 29599                      1
# 6899                       1
# 29598                      1
# 26716                      1
# 12954                      1
# 26543                      1
# 17626                      1
# 27513                      0
#
# Var1
#         Customer_ID      Var1     Var2 Group Category Rating  \
# 24823       376891  2909.776  317.380    G2       C5   Gold
# 16613      3602967  2094.866  178.064    G5       C5   Gold
# 14782      4717256  1988.040  123.931    G3       C2   Gold
# 23441      7182057  1784.045  122.195    G5       C5   Gold
# 16812      6627980  1700.419  161.761    G3       C2   Gold
# 21843      1501776  1668.433  282.688    G3       C2   Gold
# 864        6835717  1664.339  118.314    G5       C2   Gold
# 20700      1988261  1621.965   73.453    G3       C2   Gold
# 29516      2010625  1601.486   76.933    G3       C2   Gold
# 5747       1859278  1594.592  190.876    G1       C2   Gold
#
#        Purchased_ABC_product
# 24823                      1
# 16613                      1
# 14782                      1
# 23441                      1
# 16812                      1
# 21843                      1
# 864                        1
# 20700                      1
# 29516                      1
# 5747                       1
#
# Var2
#         Customer_ID      Var1     Var2 Group Category Rating  \
# 24823       376891  2909.776  317.380    G2       C5   Gold
# 21843      1501776  1668.433  282.688    G3       C2   Gold
# 3309       1951085  1408.964  204.999    G3       C5   Gold
# 5747       1859278  1594.592  190.876    G1       C2   Gold
# 16613      3602967  2094.866  178.064    G5       C5   Gold
# 16812      6627980  1700.419  161.761    G3       C2   Gold
# 13200      3199551   674.023  146.085    G4       C5   Gold
# 9452       2276443  1569.785  145.206    G3       C2   Gold
# 1326       5428696   882.613  144.295    G3       C2   Gold
# 3202       4301026   808.489  141.337    G3       C5   Gold
#
#        Purchased_ABC_product
# 24823                      1
# 21843                      1
# 3309                       1
# 5747                       1
# 16613                      1
# 16812                      1
# 13200                      1
# 9452                       1
# 1326                       1
# 3202                       1
#
# Purchased_ABC_product
#      Customer_ID     Var1    Var2 Group Category  Rating  Purchased_ABC_product
# 6        175295   41.091   2.536    G1       C4  Silver                      1
# 7        181524   96.706   9.295    G1       C1    Gold                      1
# 8        183955   82.989   5.431    G1       C2    Gold                      1
# 9        232643    2.009   1.084    G1       C1  Silver                      1
# 11       242249   73.599   7.032    G1       C2  Silver                      1
# 12       404966   15.662   1.064    G1       C1    Gold                      1
# 14       419000   26.937   2.109    G1       C1  Bronze                      1
# 23       749060  185.179  10.222    G1       C2    Gold                      1
# 27       773526   26.868   1.687    G1       C1  Bronze                      1
# 30       807011   56.444   4.771    G2       C5  Silver                      1

# %%
data_nsmallest(df)
# Out:
# Customer_ID
#         Customer_ID     Var1   Var2 Group Category  Rating  \
# 9051           647   19.878  0.425    G1       C1  Bronze
# 14970          742   79.106  6.379    G1       C3    Gold
# 20617          795   10.125  0.000    G1       C1  Bronze
# 26236          832   10.533  1.537    G1       C3  Silver
# 28527          873  116.513  3.253    G1       C3    Gold
# 21397          967    0.939  1.008    G1       C4  Bronze
# 9367           969   83.990  8.707    G1       C1  Silver
# 27965          985    2.547  0.000    G1       C3  Silver
# 1024          1005   19.226  1.388    G1       C1  Bronze
# 23269         1027    6.262  0.000    G1       C1  Bronze
#
#        Purchased_ABC_product
# 9051                       0
# 14970                      1
# 20617                      0
# 26236                      1
# 28527                      1
# 21397                      1
# 9367                       0
# 27965                      0
# 1024                       0
# 23269                      0
#
# Var1
#         Customer_ID   Var1   Var2 Group Category  Rating  Purchased_ABC_product
# 9616       2264331  0.251  0.217    G2       C4  Bronze                      0
# 24999       484004  0.254  0.000    G1       C1  Bronze                      0
# 29176      1592289  0.348  0.000    G1       C1  Bronze                      0
# 4130       6484650  0.358  0.000    G5       C3  Bronze                      0
# 23650      1585090  0.530  0.000    G1       C3  Bronze                      0
# 26580      1573199  0.560  0.000    G1       C1  Bronze                      0
# 6964       2154274  0.606  0.000    G1       C1  Bronze                      0
# 17211      1858458  0.704  0.000    G1       C3  Bronze                      0
# 18347       409003  0.728  0.000    G1       C1  Bronze                      0
# 22945       144001  0.740  0.000    G1       C3  Silver                      0
#
# Var2
#      Customer_ID    Var1  Var2 Group Category  Rating  Purchased_ABC_product
# 13       417265  22.799   0.0    G1       C1  Bronze                      0
# 16       695148   9.572   0.0    G1       C1  Bronze                      0
# 19       721109  27.819   0.0    G1       C5  Silver                      0
# 32       828848   5.608   0.0    G1       C1  Bronze                      0
# 39      1271374   8.494   0.0    G4       C1  Bronze                      0
# 48      1575603   2.510   0.0    G1       C1  Bronze                      0
# 52      1827068  11.605   0.0    G1       C1  Bronze                      0
# 59      1880022   3.934   0.0    G1       C1  Bronze                      0
# 65      1908289  16.100   0.0    G1       C1  Bronze                      0
# 70      1933892   5.201   0.0    G1       C1  Bronze                      0
#
# Purchased_ABC_product
#      Customer_ID    Var1    Var2 Group Category  Rating  Purchased_ABC_product
# 0          5518  41.534  12.123    G1       C1  Bronze                      0
# 1         40515   9.445   0.256    G1       C1  Bronze                      0
# 2         52697  37.599   3.199    G1       C2    Gold                      0
# 3         68202  81.514   1.645    G1       C1  Silver                      0
# 4        130003  46.805   1.706    G1       C1  Silver                      0
# 5        175229  19.222   2.133    G1       C3  Silver                      0
# 10       241012  16.994   0.298    G1       C1  Bronze                      0
# 13       417265  22.799   0.000    G1       C1  Bronze                      0
# 15       679877   7.730   0.917    G1       C1  Bronze                      0
# 16       695148   9.572   0.000    G1       C1  Bronze                      0

# %%
data_index_max(df)
# Out:
# Customer_ID              14045
# Var1                     24823
# Var2                     24823
# Purchased_ABC_product        6
# dtype: int64

# %%
data_index_min(df)
# Out:
# Customer_ID              9051
# Var1                     9616
# Var2                       13
# Purchased_ABC_product       0
# dtype: int64

# %%
data_check_outliers(df)
# Out:
# the upper and lower outliers are 9577484.0 and -3343604.0 of
#  Customer_ID
# the upper and lower outliers are 151.87099999999998 and -69.913 of
#  Var1
# the upper and lower outliers are 12.703 and -6.553 of
#  Var2
# the upper and lower outliers are 2.5 and -1.5 of
#  Purchased_ABC_product

# %%
data_check_outliers2(df)
# Out:
# Feature  Customer_ID
# Upper frence  	   9577484.0 	Lower frence       -3343604.0 IQR     3230272.0
#
# Feature  Var1
# Upper frence  	   151.87099999999998 	Lower frence       -69.913 IQR     55.446
#
# Feature  Var2
# Upper frence  	   12.703 	Lower frence       -6.553 IQR     4.814
#
# Feature  Purchased_ABC_product
# Upper frence  	   2.5 	Lower frence       -1.5 IQR     1.0

# %%
data_check_outliers_extreme_values(df)
# Out:
# Feature  Customer_ID
# Upper frence  	   14422892.0 	Lower frence       -8189012.0 	IQR     3230272.0
#
# Feature  Var1
# Upper frence  	   235.04 	Lower frence       -153.082 	IQR     55.446
#
# Feature  Var2
# Upper frence  	   19.924 	Lower frence       -13.774000000000001 	IQR     4.814
#
# Feature  Purchased_ABC_product
# Upper frence  	   4.0 	Lower frence       -3.0 	IQR     1.0

# %%
data_range(df)
# Out:
# Customer_ID ---Range---
#   7285267
#
#
# Var1 ---Range---
#   2909.5249999999996
#
#
# Var2 ---Range---
#   317.38
#
#
# Purchased_ABC_product ---Range---
#   1

# %%
data_df_max(df)
# Out:
# Customer_ID               7285914
# Var1                     2909.776
# Var2                       317.38
# Group                          G8
# Category                       C5
# Rating                     Silver
# Purchased_ABC_product           1
# dtype: object

# %%
data_df_min(df)
# Out:
# Customer_ID                 647
# Var1                      0.251
# Var2                        0.0
# Group                        G1
# Category                     C1
# Rating                   Bronze
# Purchased_ABC_product         0
# dtype: object

# %%
data_df_mean(df)
# Out:
# Customer_ID              3.057482e+06
# Var1                     6.486832e+01
# Var2                     4.994489e+00
# Purchased_ABC_product    5.035519e-01
# dtype: float64

# %%
data_df_medain(df)
# Out:
# Customer_ID              2192582.000
# Var1                          31.860
# Var2                           2.189
# Purchased_ABC_product          1.000
# dtype: float64

# %%
data_df_std(df)
# Out:
# Customer_ID              2.210470e+06
# Var1                     1.143733e+02
# Var2                     9.533546e+00
# Purchased_ABC_product    4.999955e-01
# dtype: float64

# %%
data_check_distribution_normality_values(df)
# Out:
# Customer_ID
#   9688892.291794673 -3573927.440712899
#
# Var1
#   407.9883544539191 -278.2517183663291
#
# Var2
#   33.59512832171336 -23.606149438316034
#
# Purchased_ABC_product
#   2.00353833084791 -0.9964346297872207

# %%
data_sample(df)
# Out:
#        Customer_ID     Var1    Var2 Group Category  Rating  \
# 24371       848299  181.856  13.572    G1       C5    Gold
# 10223      1969240   23.414   2.098    G5       C2  Bronze
# 20346      1857905   97.081  22.268    G1       C2    Gold
# 23457       470919   47.441   4.011    G1       C1  Silver
# 1221       1327542   76.732   6.418    G1       C5  Silver
# 22783      6941756   35.322   3.769    G5       C1  Bronze
# 1199        710640    8.328   1.113    G1       C3  Bronze
# 30791      5833282  111.556   4.326    G5       C2    Gold
# 16607      3224758    5.608   0.191    G5       C4  Bronze
# 1913       2105374   28.022   2.200    G5       C3  Silver
# 23664      1883970   75.199   5.434    G1       C2  Silver
# 9251       1589476    7.516   0.576    G1       C1  Bronze
# 13507      2359433   25.184   3.003    G1       C3  Silver
# 25600      7025577   13.515   1.197    G5       C1  Bronze
# 11771      1568631   16.365   0.000    G1       C1  Bronze
# 25475       811758  272.846  17.490    G1       C2    Gold
# 7569       2438208   15.249   1.637    G1       C1  Bronze
# 7839       1880423   20.766   1.990    G1       C3  Bronze
# 1129       2568833    6.758   0.000    G1       C1  Bronze
# 10222      1961215   83.054   9.718    G1       C1  Silver
#
#        Purchased_ABC_product
# 24371                      1
# 10223                      1
# 20346                      1
# 23457                      1
# 1221                       1
# 22783                      0
# 1199                       0
# 30791                      0
# 16607                      0
# 1913                       0
# 23664                      0
# 9251                       0
# 13507                      0
# 25600                      1
# 11771                      0
# 25475                      1
# 7569                       1
# 7839                       1
# 1129                       0
# 10222                      0

# %%
plt.style.use('fivethirtyeight')

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()

# %%
for col in df1.columns:
    df1[col].value_counts().head(n = 15).plot(kind = 'bar')
    plt.xlabel(col)
    plt.ylabel('Purchased_ABC_product')
    plt.show()

# %%
df1.plot(subplots = True,figsize = (15, 12),sharex = False)
plt.show()

# %%
df1.head()
# Out:
#    Customer_ID    Var1    Var2 Group Category  Rating  Purchased_ABC_product
# 0         5518  41.534  12.123    G1       C1  Bronze                      0
# 1        40515   9.445   0.256    G1       C1  Bronze                      0
# 2        52697  37.599   3.199    G1       C2    Gold                      0
# 3        68202  81.514   1.645    G1       C1  Silver                      0
# 4       130003  46.805   1.706    G1       C1  Silver                      0

# %%
for col in df1[num].columns:
    df1[col].plot()
    plt.xlabel(col)
    plt.show()

# %%
df1.Var1.plot()
df1.Var2.plot();

# %%
def box_plots(df):
    for col in df[num]:
        plt.figure(figsize=(10,6))
        df.boxplot(column=col)
        plt.show()
        
def histplot_with_bins(df):
    for col in df[num].columns:
        plt.figure(figsize=(10,6))
        df[col].hist(bins = 50) 
        plt.xlabel(col)
        plt.ylabel('Sales')
        plt.tight_layout()
        plt.show()
        
def histplot_with_bins2(df):
    for col in df[num].columns:
        plt.figure(figsize=(10,6))
        df[col].hist(bins = 100) 
        plt.xlabel(col)
        plt.ylabel('Sales')
        plt.tight_layout()
        plt.show()
        
def histplot_with_bins3(df):
    for col in df[num].columns:
        plt.figure(figsize=(10,6))
        df[col].hist(bins = 50,density = True,cumulative = True) 
        plt.xlabel(col)
        plt.ylabel('Sales')
        plt.tight_layout()
        plt.show()
        
def histplot_and_kdeplot(df):
    for col in df[num].columns:
        plt.figure(figsize=(15,6))
        plt.subplot(1,2,1)
        df[col].hist(bins = 50)
        plt.xlabel(col)
        plt.ylabel('Sales')
        plt.tight_layout()
        
        plt.subplot(1,2,2)
        sns.kdeplot(df[col])
        plt.xlabel(col)
        plt.ylabel('Sales')
        plt.tight_layout()
        plt.show()
        plt.show()
        
def histplot_and_QQplot(df):
    for col in df[num].columns:
        plt.figure(figsize=(15,6))
        plt.subplot(1,2,1)
        df[col].hist()
        plt.xlabel(col)
        plt.ylabel('Sales')
        
        plt.subplot(1,2,2)
        stats.probplot(df[col],dist='norm',plot=pylab)
        plt.xlabel(col)
        plt.ylabel('Sales')
        plt.tight_layout()
        plt.show()

# %%
df1.head()
# Out:
#    Customer_ID    Var1    Var2 Group Category  Rating  Purchased_ABC_product
# 0         5518  41.534  12.123    G1       C1  Bronze                      0
# 1        40515   9.445   0.256    G1       C1  Bronze                      0
# 2        52697  37.599   3.199    G1       C2    Gold                      0
# 3        68202  81.514   1.645    G1       C1  Silver                      0
# 4       130003  46.805   1.706    G1       C1  Silver                      0

# %%
box_plots(df1)

# %%
histplot_with_bins(df1)

# %%
histplot_with_bins2(df1)

# %%
histplot_with_bins3(df1)

# %%
histplot_and_QQplot(df1)

# %%
# we will be using df2 for this Eda

# if u want to change background style use the below

# plt.style.use('fivethirtyeight')
# plt.style.use('ggplot')

#----------------------------------------------------Bar plot--------------------------------------
def numeric_bar(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.barplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def numeric_bar_point(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.barplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        sns.pointplot(x=col,y='Purchased_ABC_product',data=df2,color='Black')
        plt.xlabel(col)
        plt.ylabel('Survived')
        plt.tight_layout()
        plt.show()

def cat_bar(df):
     for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.barplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def cat_bar_point(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.barplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        sns.pointplot(x=col,y='Purchased_ABC_product',data=df2,color='Black')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def numeric_bar_stripplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.barplot(x=col,y='Purchased_ABC_product',data=df2)
        sns.stripplot(x=col,y='Purchased_ABC_product',data=df2,jitter=True,color='Black')
        plt.tight_layout()
        plt.show()
        
def cat_bar_stripplot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.barplot(x=col,y='Purchased_ABC_product',data=df2)
        sns.stripplot(x=col,y='Purchased_ABC_product',data=df2,jitter=True,color='Black')
        plt.tight_layout()
        plt.show()
        
#----------------------------------------------------Box plot-------------------------------------------
def numeric_box(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.boxplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def cat_box(df):
     for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.boxplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def numeric_box_point(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.boxplot(x=col,y='Purchased_ABC_product',data=df2)
        sns.pointplot(x=col,y='Purchased_ABC_product',data=df2,color='Black')
        plt.tight_layout()
        plt.show()
        
def cat_box_point(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.boxplot(x=col,y='Purchased_ABC_product',data=df2)
        sns.pointplot(x=col,y='Purchased_ABC_product',data=df2,color='Black')
        plt.tight_layout()
        plt.show()
        
def numeric_box_stripplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.boxplot(x=col,y='Purchased_ABC_product',data=df2)
        sns.stripplot(x=col,y='Purchased_ABC_product',data=df2,jitter=True,edgecolor='gray')
        plt.tight_layout()
        plt.show()
        
def cat_box_stripplot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.boxplot(x=col,y='Purchased_ABC_product',data=df2)
        sns.stripplot(x=col,y='Purchased_ABC_product',data=df2,jitter=True,edgecolor='gray')
        plt.tight_layout()
        plt.show()
        
#----------------------------------------------------Boxen plot------------------------------------           
def numeric_boxen_plot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.boxenplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show() 
        
def cat_boxen_plot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.boxenplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def numeric_boxen_point_plot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.boxenplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        sns.pointplot(x=col,y='Purchased_ABC_product',data=df2,color='Black')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show() 
        
def cat_boxen_point_plot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.boxenplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        sns.pointplot(x=col,y='Purchased_ABC_product',data=df2,color='Black')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show() 
        
def numeric_boxen_stripplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.boxenplot(x=col,y='Purchased_ABC_product',data=df2)
        sns.stripplot(x=col,y='Purchased_ABC_product',data=df2,jitter=True,edgecolor='gray')
        plt.tight_layout()
        plt.show()
        
def cat_boxen_stripplot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.boxenplot(x=col,y='Purchased_ABC_product',data=df2)
        sns.stripplot(x=col,y='Purchased_ABC_product',data=df2,jitter=True,edgecolor='gray')
        plt.tight_layout()
        plt.show()
        
#-------------------------------------------------------VIOLIN Plot-----------------------------------         
def numeric_violinplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.violinplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def cat_violinplot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.violinplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def numeric_violinplot_stripplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.violinplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        sns.stripplot(x=col,y=df2['Purchased_ABC_product'],data=df2,jitter=True,edgecolor='gray')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def cat_violinplot_stripplot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.violinplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        sns.stripplot(x=col,y=df2['Purchased_ABC_product'],data=df2,jitter=True,edgecolor='gray')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
#-------------------------------------------------------Joint Plot----------------------------------
def numeric_joint(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.jointplot(x=col,y=df2['Purchased_ABC_product'],data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def numeric_joint_reg(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.jointplot(x=col,y='Purchased_ABC_product',data=df2,kind='reg')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def numeric_joint_hex(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.jointplot(x=col,y=df2['Purchased_ABC_product'],data=df2,kind='hex',color='g')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def numeric_joint_hex2(df):
    for col in df[num].columns:
        plt.figure(figsize=(18,9))
        sns.jointplot(x=col,y='Purchased_ABC_product',data=df,kind='hex')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def numeric_joint_reg(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.jointplot(x=col,y='Purchased_ABC_product',data=df2,kind='reg')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def numeric_joint_kde(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.jointplot(x=col,y='Purchased_ABC_product',data=df2,color='r',kind='kde')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def numeric_joint_kde2(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.jointplot(x=col,y='Purchased_ABC_product',data=df2,color='magenta',kind='kde')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
#----------------------------------------------------Lm Plot-------------------------------------- 
def numeric_lm_plot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.lmplot(x=col,y='Purchased_ABC_product',data=df2,aspect=1,height=8,col = None)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()

#----------------------------------------------------KDE Plot--------------------------------------
def numeric_kde(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.kdeplot(data=df2[col])
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
#------------------------------------------------------Numeric Relationship------------------------       
def numeric_linear_Relation(df):
    rows = 3
    cols = 2
    fig,ax = plt.subplots(nrows=rows,ncols=cols,figsize=(16,11))
    col = df2[num].columns
    index = 0
    for i in range(rows):
        for j in range(cols):
            sns.regplot(x=df2[col[index]],y=df2['Purchased_ABC_product'],ax=ax[i][j])
        index = index + 1
        
#----------------------------------------------------Cat Plot-------------------------------------
def numeric_and_cat_catplot(df):
    for col in df2.columns:
        plt.figure(figsize=(18,9))
        sns.catplot(data=df2,x=col,y='Purchased_ABC_product')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def numeric_and_cat_catplot_pointplot(df):
    for col in df2.columns:
        plt.figure(figsize=(18,9))
        sns.catplot(data=df2,x=col,y='Purchased_ABC_product')
        sns.pointplot(x = col,y ='Purchased_ABC_product',data=df2,color='Black')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()

#-------------------------------------------------------Stripplot Plot---------------------------    
def numeric_stripplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.stripplot(x=col,y=df2['Purchased_ABC_product'],data=df2,jitter=True,edgecolor='gray',size=10,palette='winter',orient='v')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
#-------------------------------------------------------swarmplot Plot---------------------------   
def numeric_swarmplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.swarmplot(x=col,y='Purchased_ABC_product',data=df2)
        plt.xlabel(col)
        plt.ylabel("Purchased_ABC_product")
        plt.tight_layout()
        plt.show()
        
def cat_swarmplot(df):
    for col in df2[cat].columns:
        plt.figure(figsize=(12,6))
        sns.swarmplot(x=col,y='Purchased_ABC_product',data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
#----------------------------------------------------Scatter-Plot-----------------------------------
def numeric_scatter(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        plt.scatter(x=col,y='Purchased_ABC_product',data=df2)
        plt.tight_layout()
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.show() 
        
def numeric_scatter2(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        plt.scatter(x=col,y='Purchased_ABC_product',data=df2)
        plt.tight_layout()
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.axhline(15,color='Black')
        plt.show()   
        
def numeric_scatter3(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        plt.scatter(x=col,y='Purchased_ABC_product',data=df2)
        plt.tight_layout()
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.axhline(15,color='Black')
        plt.axvline(50,color='Black')
        plt.show()        
              
#-------------------------------------------------------factor Plot-----------------------------------     
def numeric_factorplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.factorplot(x=col,y='Purchased_ABC_product',data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
#-------------------------------------------------------Resid Plot--------------------------------------    
def numeric_residplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.residplot(x=col,y='Purchased_ABC_product',data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
#-------------------------------------------------------Dis Plot-----------------------------------------      
def numeric_dis(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.distplot(df2[col],color='red')
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
def numeric_dis2(df):
    rows = 2
    cols = 2
    fig,ax = plt.subplots(nrows=rows,ncols=cols,figsize=(16,10))
    col = df2[num].columns
    index = 0
    for i in range(rows):
        for j in range(cols):
            sns.distplot(df2[col[index]],ax=ax[i][j])
            index = index + 1
    plt.tight_layout()
    plt.show()
        
#------------------------------------------------------Pandas  Plot-------------------------------------
def numeric_pandas_plot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        plt.plot(col,'Purchased_ABC_product',data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
#------------------------------------------------------Pandas bar Plot-----------------------------------
def numeric_pandas_bar(df):
    for col in df2[num].columns:
        plt.figure(figsize=(15,6))
        plt.bar(col,'Purchased_ABC_product',data=df2)
        plt.xlabel(col)
        plt.ylabel("Purchased_ABC_product")
        plt.tight_layout()
        plt.show()
        
def cat_pandas_bar(df):
     for col in df2[cat].columns:
        plt.figure(figsize=(15,6))
        plt.bar(col,'Purchased_ABC_product',data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
#------------------------------------------------------Line Plot------------------------------------------
def numeric_lineplot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        sns.lineplot(x=col,y='Purchased_ABC_product',data=df2)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
#------------------------------------------------------Scipy Plot------------------------------------------    
def numeric_scipy_prob(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,6))
        st.probplot(df2[col],plot=plt)
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
#-----------------------------------------------------Numeric Value Counts Plot------------------------------
def numeric_value_counts(df):
    for col in df2[num]:
        plt.figure(figsize=(12,6))
        plt.plot(df2[col].value_counts())
        plt.xlabel(col)
        plt.ylabel('Purchased_ABC_product')
        plt.tight_layout()
        plt.show()
        
#------------------------------------------------------Pie and bar plot--------------------------------------   
def numeric_pie_and_bar(df):
    for col in df2[num].columns:
        fig,ax=plt.subplots(1,2,figsize=(18,8))
        df2[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
        ax[0].set_title(col)
        ax[0].set_ylabel(col)
        sns.countplot(col,data=df2,ax=ax[1],order=df2[col].value_counts().index)
        ax[1].set_title(col)
        plt.show()
        
def cat_pie_and_bar(df):
    for col in df2[cat].columns:
        fig,ax=plt.subplots(1,2,figsize=(18,8))
        df2[col].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=True)
        ax[0].set_title(col)
        ax[0].set_ylabel(col)
        sns.countplot(col,data=df2,ax=ax[1],order=df2[col].value_counts().index)
        ax[1].set_title(col)
        plt.show()
        
#------------------------------------------------------barh and pie plot------------------------------------
def numeric_barh_and_pie(df):
    for col in df2[num].columns:
        fig,ax=plt.subplots(1,2,figsize=(15,8))
        clr = ("blue", "forestgreen", "gold", "red", "purple",'cadetblue','hotpink','orange','darksalmon','brown')
        df3[col].value_counts().sort_values(ascending=False).sort_values().plot(kind='barh',color=clr,ax=ax[0])
        ax[0].set_title("wheelbase",size=20)
        ax[0].set_xlabel('wheelbase',size=18)
        count=df3[col].value_counts()
        groups=list(df3[col].value_counts().index)
        counts=list(count)
        counts.append(count.agg(sum)-count.agg('sum'))
        groups.append('Other')
        type_dict=pd.DataFrame({"group":groups,"counts":counts})
        clr1=('brown','darksalmon','orange','hotpink','cadetblue','purple','red','gold','forestgreen','blue','plum')
        qx=type_dict.plot(kind='pie',y='counts',labels=groups,colors=clr1,autopct='%1.1f%%',pctdistance=0.9,radius=1.2,ax=ax[1])
        plt.legend(loc=0, bbox_to_anchor=(1.15,0.4)) 
        plt.subplots_adjust(wspace =0.5, hspace =0)
        plt.ioff()
        plt.ylabel('')
        plt.show()
        
def cat_barh_and_pie(df):
    for col in df2[cat].columns:
        fig,ax=plt.subplots(1,2,figsize=(15,8))
        clr = ("blue", "forestgreen", "gold", "red", "purple",'cadetblue','hotpink','orange','darksalmon','brown')
        df2[col].value_counts().sort_values(ascending=False).sort_values().plot(kind='barh',color=clr,ax=ax[0])
        ax[0].set_title("wheelbase",size=20)
        ax[0].set_xlabel('wheelbase',size=18)
        count=df2[col].value_counts()
        groups=list(df2[col].value_counts().index)
        counts=list(count)
        counts.append(count.agg(sum)-count.agg('sum'))
        groups.append('Other')
        type_dict=pd.DataFrame({"group":groups,"counts":counts})
        clr1=('brown','darksalmon','orange','hotpink','cadetblue','purple','red','gold','forestgreen','blue','plum')
        qx=type_dict.plot(kind='pie',y='counts',labels=groups,colors=clr1,autopct='%1.1f%%',pctdistance=0.9,radius=1.2,ax=ax[1])
        plt.legend(loc=0, bbox_to_anchor=(1.15,0.4)) 
        plt.subplots_adjust(wspace =0.5, hspace =0)
        plt.ioff()
        plt.ylabel('')
        plt.show()
        
#------------------------------------------------------dis and scatter sub plot---------------------------   
def numeric_sub_plot(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,5))
        plt.subplot(1,2,1)
        g = sns.distplot((df2[col] + 1))
        plt.subplot(1,2,2)
        plt.scatter(range(df2.shape[0]), np.sort(np.log(df2[col]+1).values))
        plt.xticks(rotation=45)
        plt.show() 
        
def numeric_sub_plot2(df):
    for col in df2[num].columns:
        plt.figure(figsize=(12,5))
        plt.subplot(1,2,1)
        g = sns.distplot(df2[col].values, bins=100, kde=False)
        plt.subplot(1,2,2)
        plt.scatter(range(df2.shape[0]), np.sort(np.log(df2[col]+1).values))
        plt.xticks(rotation=45)
        plt.show() 
        
#------------------------------------------------------hist sub plot-----------------------------------------      
def numeric_two_hist(df):
    for col in df2[num].columns:
        fig,axes=plt.subplots(nrows=2,ncols=1)
        df2.plot(kind='hist',y=col,bins=50,range=(0,100),density=True,ax=axes[0])
        df2.plot(kind='hist',y=col,bins=100,density=True,ax=axes[1],cumulative=True)
        plt.show()  
        
#----------------------------------------------------Dis and Kde sub plot--------------------------------------   
def numeric_displot_and_kde(df):
    plt.figure(figsize=(20,25))
    i = 0
    for item in df2[num].columns:
        i += 1
        plt.subplot(8, 2, i)
        sns.distplot(df2[item], rug=True, rug_kws={"color": "b"},kde=True,
                 kde_kws={"color": "blue", "lw": 5, "label": "KDE"},
                 hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "blue"},label="{0}".format(item))
plt.show()

#----------------------------------------------------Dis and Kde sub plot---------------------------------------    
def numeric_dis_and_prob_plot(df):
    for col in df2[num].columns:
        sns.distplot(df2[col], fit=norm);
        fig = plt.figure()
        res = stats.probplot(df2[col], plot=plt) 
        fig = plt.figure()
        
#----------------------------------------------------target sub plot----------------------------------------------
def target_subplot(df):
    plt.figure(figsize=(14,6))
    plt.subplot(1,2,1)
    sns.boxplot(df2.Sales)
    plt.subplot(1,2,2)
    sns.distplot(df2.Sales,bins=20)
    plt.show()
    
#----------------------------------------------------Numeric sub and reg plot--------------------------------------         
def numeric_sub_plot_reg_and_target(df):
    rows = 2
    cols = 2
    fig,ax = plt.subplots(nrows=rows,ncols=cols,figsize=(16,35))
    col = df2[num].columns
    index = 0
    for i in range(rows):
        for j in range(cols):
            sns.regplot(x=df2[col[index]],y=df2['Survived'],ax=ax[i][j])
            index = index + 1    
plt.show()

#----------------------------------------------------Learning Curve plot--------------------------------------------
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Validation score")

    plt.legend(loc="best")
    return plt

# %%
df1.head()
# Out:
#    Customer_ID    Var1    Var2 Group Category  Rating  Purchased_ABC_product
# 0         5518  41.534  12.123    G1       C1  Bronze                      0
# 1        40515   9.445   0.256    G1       C1  Bronze                      0
# 2        52697  37.599   3.199    G1       C2    Gold                      0
# 3        68202  81.514   1.645    G1       C1  Silver                      0
# 4       130003  46.805   1.706    G1       C1  Silver                      0

# %%
cat_bar(df2)

# %%
cat_bar_point(df2)

# %%
cat_bar_stripplot(df2)

# %%
cat_box(df2)

# %%
cat_box_stripplot(df2)

# %%
cat_boxen_plot(df2)

# %%
cat_pie_and_bar(df2)

# %%
cat_barh_and_pie(df2)

# %%
df.head()
# Out:
#    Customer_ID    Var1    Var2 Group Category  Rating  Purchased_ABC_product
# 0         5518  41.534  12.123    G1       C1  Bronze                      0
# 1        40515   9.445   0.256    G1       C1  Bronze                      0
# 2        52697  37.599   3.199    G1       C2    Gold                      0
# 3        68202  81.514   1.645    G1       C1  Silver                      0
# 4       130003  46.805   1.706    G1       C1  Silver                      0

# %%
label = LabelEncoder()

# %%
df['Group'] = label.fit_transform(df['Group'])

df['Category'] = label.fit_transform(df['Category'])

df['Rating'] = label.fit_transform(df['Rating'])

# %%
df.head()
# Out:
#    Customer_ID    Var1    Var2  Group  Category  Rating  Purchased_ABC_product
# 0         5518  41.534  12.123      0         0       0                      0
# 1        40515   9.445   0.256      0         0       0                      0
# 2        52697  37.599   3.199      0         1       1                      0
# 3        68202  81.514   1.645      0         0       2                      0
# 4       130003  46.805   1.706      0         0       2                      0

# %%
Scalar = StandardScaler()

# %%
X = df.drop('Purchased_ABC_product',axis = 1)

# %%
y = df['Purchased_ABC_product']

# %%
X.head()
# Out:
#    Customer_ID    Var1    Var2  Group  Category  Rating
# 0         5518  41.534  12.123      0         0       0
# 1        40515   9.445   0.256      0         0       0
# 2        52697  37.599   3.199      0         1       1
# 3        68202  81.514   1.645      0         0       2
# 4       130003  46.805   1.706      0         0       2

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Purchased_ABC_product, dtype: int64

# %%
np.random.seed(42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

print('\n Split_data_shapes')
print('\nX_train:\n',  X_train.shape)
print('\ny_train:\n',  y_train.shape)
print('\nX_test:\n',   X_train.shape)
print('\ny_test:\n',   X_test.shape)
# Out:
#  Split_data_shapes
#
# X_train:
#  (21580, 6)
#
# y_train:
#  (21580,)
#
# X_test:
#  (21580, 6)
#
# y_test:
#  (9249, 6)

# %%
print(y_train.mean())
print("\n ")
print(y_test.mean())
# Out:
# 0.5056533827618165
#
#
# 0.4986485025408152

# %%
print("Before Scaling")
print(" ")
X_train.head()
# Out:
# Before Scaling
#        Customer_ID    Var1   Var2  Group  Category  Rating
# 23299      1215515  36.316  1.533      0         0       2
# 18158      3978786  13.383  1.679      4         2       2
# 18443      4872988  50.287  4.332      4         0       2
# 5957       4360789   0.944  0.000      0         0       0
# 24549      1591214  11.798  1.850      0         4       1

# %%
X_train_scaled = Scalar.fit_transform(X_train)

X_train = pd.DataFrame(X_train_scaled,index=X_train.index,columns=X_train.columns)

X_test_scaled = Scalar.fit_transform(X_test)

X_test = pd.DataFrame(X_test_scaled,index=X_test.index,columns=X_test.columns)

# %%
print("After Scaling")
print(" ")
X_train.head()
# Out:
# After Scaling
#        Customer_ID      Var1      Var2     Group  Category    Rating
# 23299    -0.837079 -0.249056 -0.359568 -0.737768 -0.860765  1.298203
# 18158     0.414200 -0.445233 -0.344632  1.453929  0.612823  1.298203
# 18443     0.819117 -0.129543 -0.073225  1.453929 -0.860765  1.298203
# 5957      0.587181 -0.551641 -0.516397 -0.737768 -0.860765 -0.943373
# 24549    -0.666953 -0.458792 -0.327138 -0.737768  2.086410  0.177415

# %%
def show_All_scores(model):
    train = model.predict(X_train)
    test  = model.predict(X_test)
   
    print("\n Training f1_score \n",f1_score(y_train, train))
    print("\n \t Testing f1_score \n",f1_score(y_test, test))
    
    print("\n Training precision_score \n",precision_score(y_train, train))
    print("\n \t Testing precision_score \n", precision_score(y_test, test))
    
    print("\n Training recall_score \n", recall_score(y_train, train))
    print("\n \t Testing recall_score \n", recall_score(y_test, test))
    
    print("\n Training accuracy_score \n", accuracy_score(y_train, train))
    print("\n \t Testing accuracy_score \n", accuracy_score(y_test, test)) 
    
    print("\n Training roc_auc_score \n", roc_auc_score(y_train, train))
    print("\n \t Testing roc_auc_score \n", roc_auc_score(y_test, test)) 
    
def evaluate_metric(y_test,pred):
    accuracy  = accuracy_score(y_test,pred)
    f1        = f1_score(y_test,pred)
    recall    = recall_score(y_test,pred)
    precision = precision_score(y_test,pred)
    
    metric_dict = {"accuracy":round(accuracy,2),
                  "Precision":round(precision,2),
                  "recall":round(recall,2),
                  "F1":round(f1,2)}
    
    print(f"accuracy:{accuracy * 100:.2f}%")
    print(f"Precision:{precision:.2f}")
    print(f"Recall:{recall:.2f}")
    print(f"f1_score:{f1:.2f}")
    return metric_dict

# %%
def all_algorithms_with_default_parameters():
    models = {
    'Linear Regression':LogisticRegression(),
    'Decision Tree':DecisionTreeClassifier(),
    'Random Forest Regression':RandomForestClassifier(),
    'Svm':SVC(),
    "KNN":KNeighborsClassifier(),
    'Gradient Boosting':GradientBoostingClassifier(),
     "XGBoostRegressor":XGBClassifier(),
     "LGBoostRegressor":LGBMClassifier(),
    "AdaBoostRegressor":AdaBoostClassifier()}
    mn,f1,precision,recall,accuracy,roc_auc, = [],[],[],[],[],[]
    
    for model_name,model in models.items():
        model.fit(X_train, y_train)
        pred = model.predict(X_test)
        mn.append(model_name)
        f1.append(f1_score(y_test,pred))
        precision.append(precision_score(y_test,pred))
        recall.append(recall_score(y_test,pred))
        accuracy.append(accuracy_score(y_test,pred))
        print('Done with ', model_name)
        
        
    results = pd.DataFrame()
    results['Model'] = mn
    results['F1 Score'] = f1
    results['Precision'] = precision
    results['recall'] = recall
    results['accuracy'] = accuracy
    #results['Roc_Auc'] = roc_auc
    results = results.sort_values(by=['accuracy'],ascending=False)
    return results.style.background_gradient()

# %%
all_algorithms_with_default_parameters()
# Out:
# Done with  Linear Regression
# Done with  Decision Tree
# Done with  Random Forest Regression
# Done with  Svm
# Done with  KNN
# Done with  Gradient Boosting
# [15:11:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Done with  XGBoostRegressor
# Done with  LGBoostRegressor
# Done with  AdaBoostRegressor
# <style  type="text/css" >
# #T_75ce2_row0_col1,#T_75ce2_row0_col3,#T_75ce2_row0_col4,#T_75ce2_row1_col4,#T_75ce2_row4_col2{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_75ce2_row0_col2{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_75ce2_row1_col1{
#             background-color:  #308cbe;
#             color:  #000000;
#         }#T_75ce2_row1_col2{
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }#T_75ce2_row1_col3{
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }#T_75ce2_row2_col1{
#             background-color:  #034369;
#             color:  #f1f1f1;
#         }#T_75ce2_row2_col2{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_75ce2_row2_col3{
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }#T_75ce2_row2_col4{
#             background-color:  #023d60;
#             color:  #f1f1f1;
#         }#T_75ce2_row3_col1{
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }#T_75ce2_row3_col2{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_75ce2_row3_col3{
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }#T_75ce2_row3_col4{
#             background-color:  #03466e;
#             color:  #f1f1f1;
#         }#T_75ce2_row4_col1{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_75ce2_row4_col3,#T_75ce2_row8_col1,#T_75ce2_row8_col2,#T_75ce2_row8_col4{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_75ce2_row4_col4{
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }#T_75ce2_row5_col1{
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }#T_75ce2_row5_col2{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_75ce2_row5_col3{
#             background-color:  #045280;
#             color:  #f1f1f1;
#         }#T_75ce2_row5_col4{
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }#T_75ce2_row6_col1{
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }#T_75ce2_row6_col2{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_75ce2_row6_col3{
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }#T_75ce2_row6_col4{
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }#T_75ce2_row7_col1{
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }#T_75ce2_row7_col2{
#             background-color:  #a7bddb;
#             color:  #000000;
#         }#T_75ce2_row7_col3{
#             background-color:  #63a2cb;
#             color:  #000000;
#         }#T_75ce2_row7_col4{
#             background-color:  #2786bb;
#             color:  #000000;
#         }#T_75ce2_row8_col3{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }</style><table id="T_75ce2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >F1 Score</th>        <th class="col_heading level0 col2" >Precision</th>        <th class="col_heading level0 col3" >recall</th>        <th class="col_heading level0 col4" >accuracy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_75ce2_level0_row0" class="row_heading level0 row0" >8</th>
#                         <td id="T_75ce2_row0_col0" class="data row0 col0" >AdaBoostRegressor</td>
#                         <td id="T_75ce2_row0_col1" class="data row0 col1" >0.771232</td>
#                         <td id="T_75ce2_row0_col2" class="data row0 col2" >0.731016</td>
#                         <td id="T_75ce2_row0_col3" class="data row0 col3" >0.816132</td>
#                         <td id="T_75ce2_row0_col4" class="data row0 col4" >0.758568</td>
#             </tr>
#             <tr>
#                         <th id="T_75ce2_level0_row1" class="row_heading level0 row1" >3</th>
#                         <td id="T_75ce2_row1_col0" class="data row1 col0" >Svm</td>
#                         <td id="T_75ce2_row1_col1" class="data row1 col1" >0.745878</td>
#                         <td id="T_75ce2_row1_col2" class="data row1 col2" >0.784126</td>
#                         <td id="T_75ce2_row1_col3" class="data row1 col3" >0.711188</td>
#                         <td id="T_75ce2_row1_col4" class="data row1 col4" >0.758352</td>
#             </tr>
#             <tr>
#                         <th id="T_75ce2_level0_row2" class="row_heading level0 row2" >5</th>
#                         <td id="T_75ce2_row2_col0" class="data row2 col0" >Gradient Boosting</td>
#                         <td id="T_75ce2_row2_col1" class="data row2 col1" >0.768390</td>
#                         <td id="T_75ce2_row2_col2" class="data row2 col2" >0.732927</td>
#                         <td id="T_75ce2_row2_col3" class="data row2 col3" >0.807459</td>
#                         <td id="T_75ce2_row2_col4" class="data row2 col4" >0.757271</td>
#             </tr>
#             <tr>
#                         <th id="T_75ce2_level0_row3" class="row_heading level0 row3" >7</th>
#                         <td id="T_75ce2_row3_col0" class="data row3 col0" >LGBoostRegressor</td>
#                         <td id="T_75ce2_row3_col1" class="data row3 col1" >0.766226</td>
#                         <td id="T_75ce2_row3_col2" class="data row3 col2" >0.732030</td>
#                         <td id="T_75ce2_row3_col3" class="data row3 col3" >0.803773</td>
#                         <td id="T_75ce2_row3_col4" class="data row3 col4" >0.755433</td>
#             </tr>
#             <tr>
#                         <th id="T_75ce2_level0_row4" class="row_heading level0 row4" >0</th>
#                         <td id="T_75ce2_row4_col0" class="data row4 col0" >Linear Regression</td>
#                         <td id="T_75ce2_row4_col1" class="data row4 col1" >0.723733</td>
#                         <td id="T_75ce2_row4_col2" class="data row4 col2" >0.799790</td>
#                         <td id="T_75ce2_row4_col3" class="data row4 col3" >0.660885</td>
#                         <td id="T_75ce2_row4_col4" class="data row4 col4" >0.748405</td>
#             </tr>
#             <tr>
#                         <th id="T_75ce2_level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_75ce2_row5_col0" class="data row5 col0" >XGBoostRegressor</td>
#                         <td id="T_75ce2_row5_col1" class="data row5 col1" >0.760132</td>
#                         <td id="T_75ce2_row5_col2" class="data row5 col2" >0.723092</td>
#                         <td id="T_75ce2_row5_col3" class="data row5 col3" >0.801171</td>
#                         <td id="T_75ce2_row5_col4" class="data row5 col4" >0.747865</td>
#             </tr>
#             <tr>
#                         <th id="T_75ce2_level0_row6" class="row_heading level0 row6" >2</th>
#                         <td id="T_75ce2_row6_col0" class="data row6 col0" >Random Forest Regression</td>
#                         <td id="T_75ce2_row6_col1" class="data row6 col1" >0.751309</td>
#                         <td id="T_75ce2_row6_col2" class="data row6 col2" >0.726794</td>
#                         <td id="T_75ce2_row6_col3" class="data row6 col3" >0.777537</td>
#                         <td id="T_75ce2_row6_col4" class="data row6 col4" >0.743324</td>
#             </tr>
#             <tr>
#                         <th id="T_75ce2_level0_row7" class="row_heading level0 row7" >4</th>
#                         <td id="T_75ce2_row7_col0" class="data row7 col0" >KNN</td>
#                         <td id="T_75ce2_row7_col1" class="data row7 col1" >0.739487</td>
#                         <td id="T_75ce2_row7_col2" class="data row7 col2" >0.735521</td>
#                         <td id="T_75ce2_row7_col3" class="data row7 col3" >0.743495</td>
#                         <td id="T_75ce2_row7_col4" class="data row7 col4"

# %%
plt.style.use("default")


# Checking accuracy score and ploting

Classfication = [LogisticRegression(),
    RandomForestClassifier(),
    DecisionTreeClassifier(),
    GradientBoostingClassifier(),
    KNeighborsClassifier(),
    SVC(),
    XGBClassifier(),
    LGBMClassifier(),
    AdaBoostClassifier()]

names = []
scores = []

for clf in Classfication:
    clf = clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    
    names.append(clf.__class__.__name__)
    scores.append(accuracy_score(y_test,pred))

score_df = pd.DataFrame({'Model': names, 'Score': scores}).set_index('Model')
print(score_df)


score_df.sort_values('Score',inplace=True)
score_df.plot(kind='barh',y='Score');
# Out:
# [15:11:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                                Score
# Model
# LogisticRegression          0.748405
# RandomForestClassifier      0.741269
# DecisionTreeClassifier      0.703319
# GradientBoostingClassifier  0.757271
# KNeighborsClassifier        0.738783
# SVC                         0.758352
# XGBClassifier               0.747865
# LGBMClassifier              0.755433
# AdaBoostClassifier          0.758568

# %%
plt.style.use("default")


# Checking f1 score and ploting

Classfication = [LogisticRegression(),
    RandomForestClassifier(),
    DecisionTreeClassifier(),
    GradientBoostingClassifier(),
    KNeighborsClassifier(),
    SVC(),
    XGBClassifier(),
    LGBMClassifier(),
    AdaBoostClassifier()]

names = []
scores = []

for clf in Classfication:
    clf = clf.fit(X_train, y_train)
    pred = clf.predict(X_test)
    
    names.append(clf.__class__.__name__)
    scores.append(f1_score(y_test,pred))

score_df = pd.DataFrame({'Model': names, 'Score': scores}).set_index('Model')
print(score_df)


score_df.sort_values('Score',inplace=True)
score_df.plot(kind='barh',y='Score');
# Out:
# [15:12:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                                Score
# Model
# LogisticRegression          0.723733
# RandomForestClassifier      0.750313
# DecisionTreeClassifier      0.698951
# GradientBoostingClassifier  0.768390
# KNeighborsClassifier        0.739487
# SVC                         0.745878
# XGBClassifier               0.760132
# LGBMClassifier              0.766226
# AdaBoostClassifier          0.771232

# %%
log = LogisticRegression()

np.random.seed(42)

log.fit(X_train,y_train)
pred = log.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# accuracy score 0.748405232998162
#
# F1 Score 0.7237326368277336
#
# Recall Score 0.6608846487424112
#
# Precision Score 0.7997900813434794
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#            0       0.71      0.84      0.77      4637
#            1       0.80      0.66      0.72      4612
#
#     accuracy                           0.75      9249
#    macro avg       0.76      0.75      0.75      9249
# weighted avg       0.76      0.75      0.75      9249
#
#
# Confusion Matrix
#   [[3874  763]
#  [1564 3048]]

# %%
rf = RandomForestClassifier()

np.random.seed(42)

rf.fit(X_train,y_train)
pred = rf.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# accuracy score 0.7431073629581576
#
# F1 Score 0.7510999371464487
#
# Recall Score 0.7773200346921075
#
# Precision Score 0.7265910012160519
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#            0       0.76      0.71      0.73      4637
#            1       0.73      0.78      0.75      4612
#
#     accuracy                           0.74      9249
#    macro avg       0.74      0.74      0.74      9249
# weighted avg       0.74      0.74      0.74      9249
#
#
# Confusion Matrix
#   [[3288 1349]
#  [1027 3585]]

# %%
dtree = DecisionTreeClassifier()

np.random.seed(42)

dtree.fit(X_train,y_train)
pred = dtree.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# accuracy score 0.7000756838577143
#
# F1 Score 0.7008841923657537
#
# Recall Score 0.704683434518647
#
# Precision Score 0.6971256971256972
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70      4637
#            1       0.70      0.70      0.70      4612
#
#     accuracy                           0.70      9249
#    macro avg       0.70      0.70      0.70      9249
# weighted avg       0.70      0.70      0.70      9249
#
#
# Confusion Matrix
#   [[3225 1412]
#  [1362 3250]]

# %%
gb = GradientBoostingClassifier()

np.random.seed(42)

gb.fit(X_train,y_train)
pred = gb.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# accuracy score 0.7572710563304141
#
# F1 Score 0.7683895594759105
#
# Recall Score 0.8074588031222897
#
# Precision Score 0.7329265892540838
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#            0       0.79      0.71      0.75      4637
#            1       0.73      0.81      0.77      4612
#
#     accuracy                           0.76      9249
#    macro avg       0.76      0.76      0.76      9249
# weighted avg       0.76      0.76      0.76      9249
#
#
# Confusion Matrix
#   [[3280 1357]
#  [ 888 3724]]

# %%
svm = SVC()

np.random.seed(42)

svm.fit(X_train,y_train)
pred = svm.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# accuracy score 0.7583522542977619
#
# F1 Score 0.7458783399658897
#
# Recall Score 0.7111882046834345
#
# Precision Score 0.7841262251972269
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#            0       0.74      0.81      0.77      4637
#            1       0.78      0.71      0.75      4612
#
#     accuracy                           0.76      9249
#    macro avg       0.76      0.76      0.76      9249
# weighted avg       0.76      0.76      0.76      9249
#
#
# Confusion Matrix
#   [[3734  903]
#  [1332 3280]]

# %%
knn = KNeighborsClassifier()

np.random.seed(42)

knn.fit(X_train,y_train)
pred = knn.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# accuracy score 0.7387825710887663
#
# F1 Score 0.7394867371145137
#
# Recall Score 0.7434952298352124
#
# Precision Score 0.7355212355212355
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#            0       0.74      0.73      0.74      4637
#            1       0.74      0.74      0.74      4612
#
#     accuracy                           0.74      9249
#    macro avg       0.74      0.74      0.74      9249
# weighted avg       0.74      0.74      0.74      9249
#
#
# Confusion Matrix
#   [[3404 1233]
#  [1183 3429]]

# %%
xg = XGBClassifier()

np.random.seed(42)

xg.fit(X_train,y_train)
pred = xg.predict(X_test)

print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# [15:13:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# accuracy score 0.7478646340144881
#
# F1 Score 0.760131660152232
#
# Recall Score 0.8011708586296618
#
# Precision Score 0.723091976516634
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#            0       0.78      0.69      0.73      4637
#            1       0.72      0.80      0.76      4612
#
#     accuracy                           0.75      9249
#    macro avg       0.75      0.75      0.75      9249
# weighted avg       0.75      0.75      0.75      9249
#
#
# Confusion Matrix
#   [[3222 1415]
#  [ 917 3695]]

# %%
log = LogisticRegression()
np.random.seed(42)
log.fit(X_train,y_train)
pred = log.predict(X_test)


# stasts Model
X_train_sm = sm.add_constant(X_train)
lr = sm.OLS(y_train,X_train_sm).fit()
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     Purchased_ABC_product   R-squared:                       0.170
# Model:                               OLS   Adj. R-squared:                  0.170
# Method:                    Least Squares   F-statistic:                     735.9
# Date:                   Wed, 15 Dec 2021   Prob (F-statistic):               0.00
# Time:                           15:13:18   Log-Likelihood:                -13652.
# No. Observations:                  21580   AIC:                         2.732e+04
# Df Residuals:                      21573   BIC:                         2.737e+04
# Df Model:                              6
# Covariance Type:               nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.5057      0.003    163.043      0.000       0.500       0.512
# Customer_ID     0.0132      0.004      3.751      0.000       0.006       0.020
# Var1            0.0056      0.007      0.860      0.390      -0.007       0.018
# Var2            0.1370      0.007     20.895      0.000       0.124       0.150
# Group           0.0136      0.004      3.829      0.000       0.007       0.021
# Category        0.0601      0.003     18.750      0.000       0.054       0.066
# Rating          0.0949      0.003     29.578      0.000       0.089       0.101
# ==============================================================================
# Omnibus:                     4888.734   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              896.288
# Skew:                           0.017   Prob(JB):                    2.36e-195
# Kurtosis:                       2.002   Cond. No.                         4.13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#       Features   VIF
# 2         Var2  4.47
# 1         Var1  4.44
# 3        Group  1.31
# 0  Customer_ID  1.29
# 4     Category  1.07
# 5       Rating  1.07

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
pred = rf.predict(X_test)

rf.feature_importances_
# Out:
# array([0.18574291, 0.2635302 , 0.43359832, 0.0186699 , 0.05144471,
#        0.04701396])

# %%
feature_importance = pd.Series(rf.feature_importances_,index=X_train.columns)
feature_importance.sort_values()
feature_importance.plot(kind='barh',figsize=(8,6))
plt.show()

# %%
plt.figure(figsize=(7,8))
features = X_train.columns
importances = rf.feature_importances_
indices = np.argsort(importances)
plt.title('Random Forest')
plt.barh(range(len(indices)), importances[indices], color='Red', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
# select from model a build in sklearn libr for feature selection

fe = SelectFromModel(RandomForestClassifier(n_estimators=100))
fe.fit(X_train,y_train)
print(fe.get_support())
print(" ")
a = X_train.columns[fe.get_support()]
print(a)
# Out:
# [ True  True  True False False False]
#
# Index(['Customer_ID', 'Var1', 'Var2'], dtype='object')

# %%
log = LogisticRegression()
log.fit(X_train[a],y_train)
pred = log.predict(X_test[a])
print("accuracy score",(accuracy_score(y_test,pred)))
print(" ")
print("F1 Score",(f1_score(y_test,pred)))
print(" ")
print("Recall Score",(recall_score(y_test,pred)))
print(" ")
print("Precision Score",(precision_score(y_test,pred)))
print(" ")
print("Classfication Report \n ",(classification_report(y_test,pred)))
print(" ")
print("Confusion Matrix \n ",(confusion_matrix(y_test,pred)))
# Out:
# accuracy score 0.7445129203157098
#
# F1 Score 0.7161561561561561
#
# Recall Score 0.646357328707719
#
# Precision Score 0.802854834365742
#
# Classfication Report
#                 precision    recall  f1-score   support
#
#            0       0.71      0.84      0.77      4637
#            1       0.80      0.65      0.72      4612
#
#     accuracy                           0.74      9249
#    macro avg       0.75      0.74      0.74      9249
# weighted avg       0.75      0.74      0.74      9249
#
#
# Confusion Matrix
#   [[3905  732]
#  [1631 2981]]

# %%
# Random Search


rf = RandomForestClassifier()

parameters = {'max_features': ['log2', 'sqrt','auto'], 
              'criterion': ['gini', 'entropy'],
              'max_depth': [2, 3, 5, 10, 15], 
              'min_samples_split': [2, 3, 4],
              'min_samples_leaf': [1, 2, 3],
              'n_estimators' : [10, 20, 30, 50, 80, 100],
              'bootstrap': [True, False]
              }

rand_search = RandomizedSearchCV(rf, 
                           parameters,
                           scoring='accuracy',
                          cv = 5,
                          n_jobs=-1,
                          verbose = 1)
np.random.seed(42)

rand_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [2, 3, 5, 10, 15],
#                                         'max_features': ['log2', 'sqrt',
#                                                          'auto'],
#                                         'min_samples_leaf': [1, 2, 3],
#                                         'min_samples_split': [2, 3, 4],
#                                         'n_estimators': [10, 20, 30, 50, 80,
#                                                          100]},
#                    scoring='accuracy', verbose=1)

# %%
rand_search.best_params_
# Out:
# {'n_estimators': 50,
#  'min_samples_split': 3,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 10,
#  'criterion': 'gini',
#  'bootstrap': False}

# %%
rand_search.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=10, max_features='sqrt',
#                        min_samples_split=3, n_estimators=50)

# %%
rf_rand =  RandomForestClassifier(bootstrap=False, max_depth=10, max_features='sqrt',
                       min_samples_split=3, n_estimators=50)


np.random.seed(42)
rf_rand.fit(X_train,y_train)
pred = rf_rand.predict(X_test)

print("Precision Score",precision_score(y_test,pred))
print("Recall Score",recall_score(y_test,pred))
print("F1 Score",f1_score(y_test,pred))
print("Accuracy Score",accuracy_score(y_test,pred))
print("Roc_Auc Score",roc_auc_score(y_test,pred))
print(" ")
print(classification_report(y_test,pred))
print(" ")
print(confusion_matrix(y_test,pred))
print(" ")
print(evaluate_metric(y_test,pred))
# Out:
# Precision Score 0.7393383818254284
# Recall Score 0.8044232437120555
# F1 Score 0.770508826583593
# Accuracy Score 0.7610552492161314
# Roc_Auc Score 0.7611721566845807
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.72      0.75      4637
#            1       0.74      0.80      0.77      4612
#
#     accuracy                           0.76      9249
#    macro avg       0.76      0.76      0.76      9249
# weighted avg       0.76      0.76      0.76      9249
#
#
# [[3329 1308]
#  [ 902 3710]]
#
# accuracy:76.11%
# Precision:0.74
# Recall:0.80
# f1_score:0.77
# {'accuracy': 0.76, 'Precision': 0.74, 'recall': 0.8, 'F1': 0.77}
